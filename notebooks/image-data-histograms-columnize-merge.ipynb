# %%
import pandas as pd

# %%
DIR = "/Users/damoncrockett/twitter-atlas/tables/"

# %%
df = pd.read_csv(DIR+"image-data-histograms_2012.csv")

# %%
df
# Out:
#     Unnamed: 0            city  \
# 0            0   Dar es Salaam
# 1            1          Almaty
# 2            2          Bogota
# 3            3           Lagos
# 4            4        Tel Aviv
# 5            5        Asuncion
# 6            6          Manila
# 7            7        Brussels
# 8            8         Bangkok
# 9            9       Amsterdam
# 10          10       Guayaquil
# 11          11           Dhaka
# 12          12        Istanbul
# 13          13         Kampala
# 14          14   Santo Domingo
# 15          15           Paris
# 16          16        Helsinki
# 17          17            Baku
# 18          18           Dubai
# 19          19      Ulan Bator
# 20          20      Montevideo
# 21          21          Mumbai
# 22          22          Sydney
# 23          23         Toronto
# 24          24    Buenos Aires
# 25          25         Beijing
# 26          26         Nairobi
# 27          27           Tokyo
# 28          28           Mecca
# ...
