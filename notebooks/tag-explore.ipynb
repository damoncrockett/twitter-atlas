# %%
import pandas as pd
import sys
sys.path.append("/Users/damoncrockett/Desktop/")
import dv
from IPython.display import display,clear_output
import time

# %% [markdown]
# # Exploring Machine Tags using Direct Visualization

# %% [markdown]
# #### Load and process data

# %%
DIR = "/Users/damoncrockett/twitter-atlas/tables/"

# %%
md = pd.read_csv(DIR+"tagged-sample.csv")

# %%
fd = pd.read_csv(DIR+"sample-vgg16.csv")

# %%
md = md[md.hue_peak!='unreadable']
md.hue_peak = md.hue_peak.apply(int)
md.val_mean = md.val_mean.apply(float)
md.sat_mean = md.sat_mean.apply(float)
fd = fd.loc[md.index]

# %% [markdown]
# #### Animated Sampling

# %%
for i in range(10):
    canvas = dv.montage(md.macpath,fd,'stage',thumb=64,sample=100)
    clear_output()
    display(canvas)
    time.sleep(2)
# Out:
# <PIL.Image.Image image mode=RGB size=832x512 at 0x114595B10>

# %% [markdown]
# #### Montage

# %%
dv.montage(md.macpath,fd,'stage',thumb=16)
# Out:
# <PIL.Image.Image image mode=RGB size=864x352 at 0x1145B18D0>

# %% [markdown]
# #### Scatter

# %%
dv.scatter(md.macpath,fd,md,'stage','hue_peak',thumb=16)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x114595610>

# %%
dv.scatter(md.macpath,fd,md,'stage','val_mean',thumb=16)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x114595C10>

# %%
dv.scatter(md.macpath,fd,md,'stage','sat_mean',thumb=16)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x114595E90>

# %% [markdown]
# #### Histogram

# %%
dv.histogram(md.macpath,fd,md,'stage','hue_peak',thumb=8,nbins=100)
# Out:
# <PIL.Image.Image image mode=RGB size=800x552 at 0x110B81A90>

# %%
dv.histogram(md.macpath,fd,md,'stage','val_mean',thumb=8,nbins=100)
# Out:
# <PIL.Image.Image image mode=RGB size=800x552 at 0x10FDEF8D0>

# %%
dv.histogram(md.macpath,fd,md,'stage','sat_mean',thumb=16,nbins=100)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1104 at 0x10FDF5F10>
